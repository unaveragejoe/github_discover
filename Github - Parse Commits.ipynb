# %%
commit_sample = {'commits': [{'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-11-01T05:27:37Z'}, 'message': "Merge branch 'master' of github.com:mohdsanadzakirizvi/Data-Science-with-Julia", 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/f8a1e33b2076ae76216c566c202ad4030fd8cdaa', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/b0335f605a2739df0211bc28fae2912489363ad7', 'sha': 'b0335f605a2739df0211bc28fae2912489363ad7'}, 'committer': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-11-01T05:27:37Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/f8a1e33b2076ae76216c566c202ad4030fd8cdaa', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'sha': '58b32c1fa8e804a2994ff19196d0e4ac6f05bd82'}, {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'sha': '6f7c1767bf83d94e8d5ec644678c85ff26369e2f'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOmY4YTFlMzNiMjA3NmFlNzYyMTZjNTY2YzIwMmFkNDAzMGZkOGNkYWE=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/f8a1e33b2076ae76216c566c202ad4030fd8cdaa', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/f8a1e33b2076ae76216c566c202ad4030fd8cdaa/comments', 'sha': 'f8a1e33b2076ae76216c566c202ad4030fd8cdaa', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-11-01T05:04:54Z'}, 'message': 'updated code in fundamentals', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/baa32c2c85d8228f03b5273bfa211143c8ac7d13', 'sha': 'baa32c2c85d8228f03b5273bfa211143c8ac7d13'}, 'committer': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-11-01T05:04:54Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/276b27e9da0a82e81f91424e3d7b578450634387', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/276b27e9da0a82e81f91424e3d7b578450634387', 'sha': '276b27e9da0a82e81f91424e3d7b578450634387'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOjU4YjMyYzFmYThlODA0YTI5OTRmZjE5MTk2ZDBlNGFjNmYwNWJkODI=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/58b32c1fa8e804a2994ff19196d0e4ac6f05bd82/comments', 'sha': '58b32c1fa8e804a2994ff19196d0e4ac6f05bd82', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': '-----BEGIN PGP SIGNATURE-----\n\\n=IQRd\n-----END PGP SIGNATURE-----\n', 'verified': True, 'reason': 'valid', 'payload': 'tree a5d8fa19987b8ed68b28628bed0a65a9e2176124\nparent 276b27e9da0a82e81f91424e3d7b578450634387\nauthor theuchiha <mohdsanadzakirizvi@users.noreply.github.com> 1509361866 +0530\ncommitter GitHub <noreply@github.com> 1509361866 +0530\n\nUpdate README.md'}, 'author': {'email': 'mohdsanadzakirizvi@users.noreply.github.com', 'name': 'theuchiha', 'date': '2017-10-30T11:11:06Z'}, 'message': 'Update README.md', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/a5d8fa19987b8ed68b28628bed0a65a9e2176124', 'sha': 'a5d8fa19987b8ed68b28628bed0a65a9e2176124'}, 'committer': {'email': 'noreply@github.com', 'name': 'GitHub', 'date': '2017-10-30T11:11:06Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4', 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}', 'id': 19864447, 'organizations_url': 'https://api.github.com/users/web-flow/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3', 'html_url': 'https://github.com/web-flow', 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions', 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}', 'received_events_url': 'https://api.github.com/users/web-flow/received_events', 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}', 'type': 'User', 'login': 'web-flow', 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/web-flow', 'followers_url': 'https://api.github.com/users/web-flow/followers', 'repos_url': 'https://api.github.com/users/web-flow/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/276b27e9da0a82e81f91424e3d7b578450634387', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/276b27e9da0a82e81f91424e3d7b578450634387', 'sha': '276b27e9da0a82e81f91424e3d7b578450634387'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOjZmN2MxNzY3YmY4M2Q5NGU4ZDVlYzY0NDY3OGM4NWZmMjYzNjllMmY=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/6f7c1767bf83d94e8d5ec644678c85ff26369e2f/comments', 'sha': '6f7c1767bf83d94e8d5ec644678c85ff26369e2f', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-22T01:54:07Z'}, 'message': 'Added viz', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/276b27e9da0a82e81f91424e3d7b578450634387', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/71e7ac8cee36a59672bd2b684da7e743a6affb0d', 'sha': '71e7ac8cee36a59672bd2b684da7e743a6affb0d'}, 'committer': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-22T01:54:07Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/276b27e9da0a82e81f91424e3d7b578450634387', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/c2f7d23dd88750212ecaabf7556b32406eb483e6', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/c2f7d23dd88750212ecaabf7556b32406eb483e6', 'sha': 'c2f7d23dd88750212ecaabf7556b32406eb483e6'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOjI3NmIyN2U5ZGEwYTgyZTgxZjkxNDI0ZTNkN2I1Nzg0NTA2MzQzODc=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/276b27e9da0a82e81f91424e3d7b578450634387', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/276b27e9da0a82e81f91424e3d7b578450634387/comments', 'sha': '276b27e9da0a82e81f91424e3d7b578450634387', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@users.noreply.github.com', 'name': 'theuchiha', 'date': '2017-10-22T01:42:04Z'}, 'message': 'Update README.md', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/c2f7d23dd88750212ecaabf7556b32406eb483e6', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/3cd608f03571049d63e439094dafe2ffe8bfe7f1', 'sha': '3cd608f03571049d63e439094dafe2ffe8bfe7f1'}, 'committer': {'email': 'noreply@github.com', 'name': 'GitHub', 'date': '2017-10-22T01:42:04Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/c2f7d23dd88750212ecaabf7556b32406eb483e6', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/19864447?v=4', 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}', 'id': 19864447, 'organizations_url': 'https://api.github.com/users/web-flow/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3', 'html_url': 'https://github.com/web-flow', 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions', 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}', 'received_events_url': 'https://api.github.com/users/web-flow/received_events', 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}', 'type': 'User', 'login': 'web-flow', 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/web-flow', 'followers_url': 'https://api.github.com/users/web-flow/followers', 'repos_url': 'https://api.github.com/users/web-flow/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'sha': 'ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOmMyZjdkMjNkZDg4NzUwMjEyZWNhYWJmNzU1NmIzMjQwNmViNDgzZTY=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/c2f7d23dd88750212ecaabf7556b32406eb483e6', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/c2f7d23dd88750212ecaabf7556b32406eb483e6/comments', 'sha': 'c2f7d23dd88750212ecaabf7556b32406eb483e6', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-21T20:06:23Z'}, 'message': 'Added .gitignore and README', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/64aa694c6d9cc23e55901971594b746a483ab770', 'sha': '64aa694c6d9cc23e55901971594b746a483ab770'}, 'committer': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-21T20:06:23Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}, 'parents': [{'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/b61f8d24284765f42d0b5884f3af936be9ef000f', 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/b61f8d24284765f42d0b5884f3af936be9ef000f', 'sha': 'b61f8d24284765f42d0b5884f3af936be9ef000f'}], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOmFiNjliM2VhNWE3YmU5N2U0N2E5NmJhNzNiZTRhM2U4MDA2ZjRlNDQ=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44/comments', 'sha': 'ab69b3ea5a7be97e47a96ba73be4a3e8006f4e44', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}, {'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-21T20:02:52Z'}, 'message': 'first data files commit', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/commits/b61f8d24284765f42d0b5884f3af936be9ef000f', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/git/trees/1a9402db528da428d82a15d176459378244b3213', 'sha': '1a9402db528da428d82a15d176459378244b3213'}, 'committer': {'email': 'mohdsanadzakirizvi@gmail.com', 'name': 'sanad', 'date': '2017-10-21T20:02:52Z'}}, 'html_url': 'https://github.com/mohdsanadzakirizvi/Data-Science-with-Julia/commit/b61f8d24284765f42d0b5884f3af936be9ef000f', 'committer': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}, 'parents': [], 'node_id': 'MDY6Q29tbWl0MTA3ODExNzEyOmI2MWY4ZDI0Mjg0NzY1ZjQyZDBiNTg4NGYzYWY5MzZiZTllZjAwMGY=', 'url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/b61f8d24284765f42d0b5884f3af936be9ef000f', 'comments_url': 'https://api.github.com/repos/mohdsanadzakirizvi/Data-Science-with-Julia/commits/b61f8d24284765f42d0b5884f3af936be9ef000f/comments', 'sha': 'b61f8d24284765f42d0b5884f3af936be9ef000f', 'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/8193234?v=4', 'following_url': 'https://api.github.com/users/mohdsanadzakirizvi/following{/other_user}', 'id': 8193234, 'organizations_url': 'https://api.github.com/users/mohdsanadzakirizvi/orgs', 'gravatar_id': '', 'node_id': 'MDQ6VXNlcjgxOTMyMzQ=', 'html_url': 'https://github.com/mohdsanadzakirizvi', 'subscriptions_url': 'https://api.github.com/users/mohdsanadzakirizvi/subscriptions', 'events_url': 'https://api.github.com/users/mohdsanadzakirizvi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohdsanadzakirizvi/received_events', 'starred_url': 'https://api.github.com/users/mohdsanadzakirizvi/starred{/owner}{/repo}', 'type': 'User', 'login': 'mohdsanadzakirizvi', 'gists_url': 'https://api.github.com/users/mohdsanadzakirizvi/gists{/gist_id}', 'site_admin': False, 'url': 'https://api.github.com/users/mohdsanadzakirizvi', 'followers_url': 'https://api.github.com/users/mohdsanadzakirizvi/followers', 'repos_url': 'https://api.github.com/users/mohdsanadzakirizvi/repos'}}], 'id': 107811712}

# %%
import numpy as np
import pandas as pd
import pprint as pprint
import pickle as pickle
# import json as json
import simplejson as json
from io import StringIO
io = StringIO()

# %%
# !pip install simplejson
# Out:
# ...
#     100% |████████████████████████████████| 81kB 2.8MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for simplejson ... done
#   Stored in directory: /Users/joe.kholodenko/Library/Caches/pip/wheels/5d/1a/1e/0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77
# Successfully built simplejson
# ...
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
x = pd.read_json('commits_json.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-683913ca3667> in <module>()
# ----> 1 x = pd.read_json('commits_json.json')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     527             )
#     528         else:
# --> 529             obj = self._get_object_parser(self.data)
#     530         self.close()
#     531         return obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
# ...

# %%
file_object = open('commits_json.json', 'r')
# file = json.dump(file_object, io)
# commit_sample = json.loads('commits_json.json', io)
# pd.read_json('commits_json.json')
# file_object.encoding(json.JSONEncoder())

# %%
x = file_object.readlines()

# %%
len(x)
# Out:
# 1379

# %%
x[1]
# Out:
# ",{'commits': [{'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'bshar@bshar-osx.local', 'name': 'Boris Sharchilev', 'date': '2017-04-14T15:48:29Z'}, 'message': 'Added CombinatorialRPCA', 'url': 'https://api.github.com/repos/bsharchilev/RobustPCA/git/commits/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/bsharchilev/RobustPCA/git/trees/330e8bab71d2dff0eaf5e663532331cf2a9086ec', 'sha': '330e8bab71d2dff0eaf5e663532331cf2a9086ec'}, 'committer': {'email': 'bshar@bshar-osx.local', 'name': 'Boris Sharchilev', 'date': '2017-04-14T15:48:29Z'}}, 'html_url': 'https://github.com/bsharchilev/RobustPCA/commit/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861', 'committer': None, 'parents': [{'url': 'https://api.github.com/repos/bsharchilev/RobustPCA/commits/8042077899e27b3a6595e2f75a5cdf039d50912d', 'html_url': 'https://github.com/bsharchilev/RobustPCA/commit/80420778
# ...

# %%
y
# Out:
# '",{\'commits\': [{\'commit\': {\'verification\': {\'signature\': None, \'verified\': False, \'reason\': \'unsigned\', \'payload\': None}, \'author\': {\'email\': \'bshar@bshar-osx.local\', \'name\': \'Boris Sharchilev\', \'date\': \'2017-04-14T15:48:29Z\'}, \'message\': \'Added CombinatorialRPCA\', \'url\': \'https://api.github.com/repos/bsharchilev/RobustPCA/git/commits/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861\', \'comment_count\': 0, \'tree\': {\'url\': \'https://api.github.com/repos/bsharchilev/RobustPCA/git/trees/330e8bab71d2dff0eaf5e663532331cf2a9086ec\', \'sha\': \'330e8bab71d2dff0eaf5e663532331cf2a9086ec\'}, \'committer\': {\'email\': \'bshar@bshar-osx.local\', \'name\': \'Boris Sharchilev\', \'date\': \'2017-04-14T15:48:29Z\'}}, \'html_url\': \'https://github.com/bsharchilev/RobustPCA/commit/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861\', \'committer\': None, \'parents\': [{\'url\': \'https://api.github.com/repos/bsharchilev/RobustPCA/commits/8042077899e27b3a6595e2f75a5cdf039d50
# ...

# %%
c
# Out:
# ['\n,']

# %%
# t = x.split('\n,')

# %%
# z = [json.loads(p) for p in x]

# %%
# t = "\n,".split(x)

# %%
x[1][1:].replace(""",'').replace("'",'"').replace("None",'"None"').replace("False",'"False"')
# Out:
#   File "<ipython-input-153-48969cfd122b>", line 1
#     x[1][1:].replace(""",'').replace("'",'"').replace("None",'"None"').replace("False",'"False"')
#                                                                                                  ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
x[0]
# Out:
# "[{'commits': [{'commit': {'verification': {'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None}, 'author': {'email': 'shoya.ishimaru@gmail.com', 'name': 'Shoya Ishimaru', 'date': '2016-04-16T11:38:54Z'}, 'message': 'Bug fix for accuracy calculation', 'url': 'https://api.github.com/repos/shoya140/zChainer/git/commits/9834f72f5db166f7d429ab385f8451566af63268', 'comment_count': 0, 'tree': {'url': 'https://api.github.com/repos/shoya140/zChainer/git/trees/e4d97f4859393a140321699fab6eebb489c7d205', 'sha': 'e4d97f4859393a140321699fab6eebb489c7d205'}, 'committer': {'email': 'shoya.ishimaru@gmail.com', 'name': 'Shoya Ishimaru', 'date': '2016-04-16T11:39:25Z'}}, 'html_url': 'https://github.com/shoya140/zChainer/commit/9834f72f5db166f7d429ab385f8451566af63268', 'committer': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1812652?v=4', 'following_url': 'https://api.github.com/users/shoya140/following{/other_user}', 'id': 1812652, 'organizations_url': 'https://ap
# ...

# %%
import re as re

r = re.sub('"message": "[A-Za-z. ]*", ', '', string)
#            'message': 'Fix conflicts when merging branch 2.6.x with master',

# %%
x2 = [
      re.sub('"message": "[A-Za-z.,-_" ]*", ', '',  
      x[i][1:].replace('"','')
      .replace("'",'"')
      .replace("None",'"null"')
      .replace("False",'"False"')
      .replace("True",'"True"') )
#       .replace("{'signature': None, 'verified': False, 'reason': 'unsigned', 'payload': None},", '')
      
#       .replace("dict",'"object"') 
#       .replace("str",'"string"') 
#       .replace("int",'"number"') 
#       .replace("long",'"number"') 
#       .replace("float",'"number"') 
#       .replace("list",'"array"') 
#       .replace("tuple",'"array"') 
#       .replace("float",'"number"') 
      for i in range(1,len(x)-1)]

# %%
x2[5]
# Out:
# '{"commits": [{"commit": {"verification": {"signature": "null", "verified": "False", "reason": "unsigned", "payload": "null"}, "author": {"email": "12213062.bjtu.edu.cn", "name": "newxuyangcao", "date": "2018-05-08T02:57:57Z"}, "url": "https://api.github.com/repos/xuyangcao/sklearn/git/commits/95d8749abf992566c29619ad74e5b6210a319884", "comment_count": 0, "tree": {"url": "https://api.github.com/repos/xuyangcao/sklearn/git/trees/bb832ffbef172da2284302b9724fcf91dd396daf", "sha": "bb832ffbef172da2284302b9724fcf91dd396daf"}, "committer": {"email": "12213062.bjtu.edu.cn", "name": "newxuyangcao", "date": "2018-05-08T02:57:57Z"}}, "html_url": "https://github.com/xuyangcao/sklearn/commit/95d8749abf992566c29619ad74e5b6210a319884", "committer": "null", "parents": [{"url": "https://api.github.com/repos/xuyangcao/sklearn/commits/89a75d84c52046390fd764cd746319609157e76f", "html_url": "https://github.com/xuyangcao/sklearn/commit/89a75d84c52046390fd764cd746319609157e76f", "sha": "89a75d84c52046390f
# ...

# %%
x2[0]
# Out:
# '{"commits": [{"commit": {"verification": {"signature": "None", "verified": "False", "reason": "unsigned", "payload": "None"}, "author": {"email": "bshar@bshar-osx.local", "name": "Boris Sharchilev", "date": "2017-04-14T15:48:29Z"}, "message": "Added CombinatorialRPCA", "url": "https://api.github.com/repos/bsharchilev/RobustPCA/git/commits/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861", "comment_count": 0, "tree": {"url": "https://api.github.com/repos/bsharchilev/RobustPCA/git/trees/330e8bab71d2dff0eaf5e663532331cf2a9086ec", "sha": "330e8bab71d2dff0eaf5e663532331cf2a9086ec"}, "committer": {"email": "bshar@bshar-osx.local", "name": "Boris Sharchilev", "date": "2017-04-14T15:48:29Z"}}, "html_url": "https://github.com/bsharchilev/RobustPCA/commit/40d6b2f05fe8371bdaa7b92efb72913c3a1c2861", "committer": "None", "parents": [{"url": "https://api.github.com/repos/bsharchilev/RobustPCA/commits/8042077899e27b3a6595e2f75a5cdf039d50912d", "html_url": "https://github.com/bsharchilev/RobustPCA/commit/8
# ...

# %%
x2[4]
# 11457
# Out:
# '{"commits": [{"commit": {"verification": {"signature": "-----BEGIN PGP SIGNATURE-----\\n\\nwsBcBAABCAAQBQJb20PlCRBK7hj4Ov3rIwAAdHIIAAWaTcUIX5gH1umapbGUEw0+\\n+qex/sXNk+tgalPXY63IS+qP1S5BaS38A8/vLyRErmLSAyt7h1ZMnAXEAXugg7+h\\ngRXL+utNR2Ws7xUjSTqGLV1iGCDSQMNagZPvYgDWsQxV7uJbelBBX+34WqBwwKT/\\nvjyIqCcI3Uek2690+s2r/CB5kizPIPbppDOM1d9VXQwWG08bjCIprk7hX9DKWoCk\\nukBcSB1GCBQN+jDBrj1JUSoRyyOP6W4PE/OrkBP6sFieiPUW00rK6ok4qwtnvZOR\\nJDXGgyfcWuCSnYZF8unqWG48FfjLEdVDAow7da4EgZcIJiDrjoM3jrALYF3Q4tg=\\n=k8WH\\n-----END PGP SIGNATURE-----\\n", "verified": "True", "reason": "valid", "payload": "tree 38d4ac7cb5256e9978019f4bf51db288a2f7b033\\nparent 3586888e782e3779bdd5f072458a476e0f5095d5\\nparent 16b8be83d378408b30553b8637be5a65464b6d3b\\nauthor Ganesh N Sivalingam <g.n.sivalingam@gmail.com> 1541096421 +0000\\ncommitter GitHub <noreply@github.com> 1541096421 +0000\\n\\nMerge pull request #8 from gnsiva/release_010\\n\\nRelease 010"}, "author": {"email": "g.n.sivalingam@gmail.com", "name": "Ganesh N
# ...

# %%
json.loads(x2[4])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-221-bb6d3612a786> in <module>()
# ----> 1 json.loads(x2[4])
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
# ...

# %%
x2[9]
# 78327
# Out:
# '{"commits": [{"commit": {"verification": {"signature": "null", "verified": "False", "reason": "unsigned", "payload": "null"}, "author": {"email": "lasanthakr77@gmail.com", "name": "Lasantha Rathnayake", "date": "2017-08-26T07:11:53Z"}, "message": "Enron email fraud detection - ready revision 1", "url": "https://api.github.com/repos/lasanthagithub/Identifying_Fraud_from_Enron_Emails_using_Machine_Learning/git/commits/06764a35fec143830828fafd2b2efeecb79f08f9", "comment_count": 0, "tree": {"url": "https://api.github.com/repos/lasanthagithub/Identifying_Fraud_from_Enron_Emails_using_Machine_Learning/git/trees/19c038f43f21ecd886b59a002ceaa75dd6ca5abe", "sha": "19c038f43f21ecd886b59a002ceaa75dd6ca5abe"}, "committer": {"email": "lasanthakr77@gmail.com", "name": "Lasantha Rathnayake", "date": "2017-08-26T07:11:53Z"}}, "html_url": "https://github.com/lasanthagithub/Identifying_Fraud_from_Enron_Emails_using_Machine_Learning/commit/06764a35fec143830828fafd2b2efeecb79f08f9", "committer": {"avat
# ...

# %%
result_1 = []
for i,v in enumerate(x2):
    try:
        result.append(json.loads(v))
    except:
        continue
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 5
# 7
# 8
# 10
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 20
# 21
# 22
# 26
# 28
# 29
# 30
# 35
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# 48
# 49
# 50
# 51
# 52
# 53
# 55
# 56
# 57
# 58
# 59
# 62
# 63
# 65
# 67
# 70
# 72
# 74
# 75
# 76
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 91
# 92
# 93
# 94
# 95
# 96
# 98
# 100
# 101
# 104
# 105
# 106
# 109
# 110
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 125
# 126
# 127
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 138
# 139
# 141
# 142
# 144
# 145
# 146
# 147
# 148
# 151
# 153
# 155
# 156
# 157
# 159
# 160
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 174
# 175
# 176
# 177
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 187
# 190
# 192
# 193
# 194
# 196
# 197
# 201
# 208
# 212
# 214
# 215
# 217
# 219
# 223
# 224
# 226
# 234
# 235
# 238
# 240
# 242
# 243
# 249
# 252
# 254
# 262
# 264
# 265
# 268
# 273
# 276
# 282
# 287
# 299
# 303
# 305
# 306
# 308
# 311
# 313
# 318
# 319
# 324
# 326
# 327
# ...

# %%
len(result_1)
# Out:
# 0

# %%
commit_author = []
for repo in x[:2]:
    print(repo[:30])
    #     print(json.dumps(repo, io))
#     for commit in repo:
#         commit_author.append((
#                              commit['author']['avatar_url'],
#                              commit['html_url'],
#                              commit['url'],
#                              commit['author']['id'],
#                              commit['commit']['author']['date'],
#                              commit['commit']['author']['email'],
#                              commit['commit']['author']['name'],
#                              commit['commit']['message']
#                              ))
    
#     pprint.pprint(x['author'])
# Out:
# '{'commits': [{'commit': {'ver
# ,{'commits': [{'commit': {'ver

# %%
commit_author_df = pd.DataFrame(commit_author)
commit_author_df.columns = ['avatar_url', 'html_url', 'url', 'id', 'date', 'email', 'name', 'message']

# %%
commit_author_df.head()
# Out:
#                                           avatar_url  \
# 0  https://avatars3.githubusercontent.com/u/81932...
# 1  https://avatars3.githubusercontent.com/u/81932...
# 2  https://avatars3.githubusercontent.com/u/81932...
# 3  https://avatars3.githubusercontent.com/u/81932...
# 4  https://avatars3.githubusercontent.com/u/81932...
#
#                                             html_url  \
# 0  https://github.com/mohdsanadzakirizvi/Data-Sci...
# 1  https://github.com/mohdsanadzakirizvi/Data-Sci...
# 2  https://github.com/mohdsanadzakirizvi/Data-Sci...
# 3  https://github.com/mohdsanadzakirizvi/Data-Sci...
# 4  https://github.com/mohdsanadzakirizvi/Data-Sci...
#
#                                                  url       id  \
# 0  https://api.github.com/repos/mohdsanadzakirizv...  8193234
# 1  https://api.github.com/repos/mohdsanadzakirizv...  8193234
# 2  https://api.github.com/repos/mohdsanadzakirizv...  8193234
# 3  https://api.github.com/repos/mohdsanadzakirizv...  8193234
# ...

# %%
from github import Github
import pickle
import numpy as np
import pandas as pd
import pickle as pickle
import pprint

from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import os
import requests
import time
import re
import random
import json
import urllib

ua = UserAgent()

# Add auth token here
g = Github("")

# %%
user_profile_page_data = []
for repo in g.search_users('unaveragejoe'):
    d = repo.raw_data
    user_profile_page_data.append([d['login'], 
                                  d['id'], 
                                  d['avatar_url'],
                                  d['url'],
                                  d['html_url'],
                                  d['email'],
                                  d['name'],
                                  d['company'],
                                  d['location'],
                                  d['hireable'],
                                  d['bio'],
                                  d['company']]
                                 )

# %%
user_profiles_df = pd.DataFrame(user_profile_page_data)
user_profiles_df.columns = ['login', 'id', 'avatar_url', 'url', 'html_url', 'email', 'name', 'company', 'location', 'hireable', 'bio', 'company']

# %%
user_profiles_df.head()
# Out:
#           login        id                                         avatar_url  \
# 0  unaveragejoe  18011210  https://avatars3.githubusercontent.com/u/18011...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/unaveragejoe  https://github.com/unaveragejoe
#
#   email               name company location hireable                bio  \
# 0  None  Joseph Kholodenko    None     None     None  Always be coding!
#
#   company
# 0    None
